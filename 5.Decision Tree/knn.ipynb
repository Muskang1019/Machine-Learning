# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('loan_approval_dataset.csv.xls')

# %% [markdown]
# we can use 2 parameters
# 1.n_neighbor=root n
# 2.metric='euclidean"|"manhattan
# - in knn we use scaling preprocessing technique to get best accuracy and we use only for small to medium datasets but not for large dataset bcoz it will take more time

# %%
x = df.drop(columns='Loan_Approved')
y=df.Loan_Approved

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %% [markdown]
# train test spli
# transformer techni
# scaling preprocessing technique
# pipeline
# model training
# model evaluation

# %%
# download dataset related to sales
