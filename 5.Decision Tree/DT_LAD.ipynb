# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor

# %%
df=pd.read_csv('loan_approval_dataset.csv.xls')

# %%
x = df.drop(columns='Loan_Approved')
y=df.Loan_Approved

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
model_1=DecisionTreeClassifier()#the node stops based on purity and impurity
model_2=DecisionTreeRegressor()#no concept of purity and impurity and it stops the node based 
#on max_depth,min_Samples_split & min_Sample_leaf
