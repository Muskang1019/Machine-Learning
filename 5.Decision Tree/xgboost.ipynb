# %%
from xgboost import XGBClassifier,XGBRegressor
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df=pd.read_csv('loan_approval_dataset.csv.xls')

# %%
df['Loan_Approved']=df['Loan_Approved'].map({'Yes':1,'No':0})

# %%
x = df.drop(columns='Loan_Approved')
y=df.Loan_Approved

# %%
obj_cols=x.select_dtypes(include='object').columns

# %%
x[obj_cols]=x[obj_cols].astype('category')

# %%
df

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
model=XGBClassifier(enable_categorical=True,n_estimators=200,learning_rate=10,max_depth=50)
model.fit(xtrain,ytrain)

# %% [markdown]
# max_depth=None,5,10,50,100
# n_estimators=50,100,150,200
# learning_rate=0.001,0.01,0.1,1.0,10,100

# %%
model.score(xtrain,ytrain)

# %%
model.score(xtest,ytest)#model is overfitting because the score on the training data 
# is higher than the score on the test data.

# %%
max_depth=None

# %% [markdown]
# search dataset for random forest classifier
# 4 datasets 1-rfc rfr 1-xgc xgbr
